# %% [markdown]
# <a href="https://colab.research.google.com/github/csernaquech/CursoDMC/blob/main/Copia_de__ProceMae_proc_tentativas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
import pandas as pd
import random
dfv = pd.read_csv('denuncias_procesadas_sum.csv',delimiter=';',encoding='ISO-8859-1')


dfv
# Out:
#      ANIO        DEPARTAMENTO                DISTRITO  \
# 0    2021                LIMA              CARABAYLLO
# 1    2021                LIMA                   COMAS
# 2    2021                LIMA             EL AGUSTINO
# 3    2021                LIMA                     ATE
# 4    2021                LIMA           INDEPENDENCIA
# ..    ...                 ...                     ...
# 190  2023                LIMA                   RIMAC
# 191  2023                LIMA              SAN MIGUEL
# 192  2023                LIMA           INDEPENDENCIA
# 193  2023                LIMA  SAN JUAN DE LURIGANCHO
# 194  2023  LIMA METROPOLITANA                   BRE¥A
#
#                   CENTRO-ATENCION  CASOS-MUJERES  V.PSICOLOGICA  V.FISICA  \
# 0                  CEM CARABAYLLO            466            223       196
# 1                       CEM COMAS            317            126       136
# 2                 CEM EL AGUSTINO            220             42       176
# ...

# %%
dfnew = pd.DataFrame(columns=[
    'ANIO',
    'DEPARTAMENTO',
    'DISTRITO',
    'CENTRO-ATENCION',
    'CASOS-MUJERES',
    'VIOLENCIA',
    'EDAD'
 ])

# %%
for indice, fila in dfv.iterrows():
    #if fila['CASOS-MUJERES'] == 31:

        #V.PSICOLOGICA
        EdadRng1  = fila['6_11']
        for i in range(1, EdadRng1 + 1):
            nueva_fila = {'ANIO':             fila['ANIO'],
                          'DEPARTAMENTO':     fila['DEPARTAMENTO'],
                          'DISTRITO':         fila['DISTRITO'],
                          'CENTRO-ATENCION':  fila['CENTRO-ATENCION'],
                          'CASOS-MUJERES':    fila['CASOS-MUJERES'],
                          'VIOLENCIA':        'Psicologica',
                          'EDAD':             random.randint(10, 45)
                          #'EDAD':             random.randint(6, 11)
                          }
            dfnew = dfnew.append(nueva_fila, ignore_index=True)

        EdadRng2  = fila['18_29']
        for i in range(1, EdadRng2 + 1):
            nueva_fila = {'ANIO':             fila['ANIO'],
                          'DEPARTAMENTO':     fila['DEPARTAMENTO'],
                          'DISTRITO':         fila['DISTRITO'],
                          'CENTRO-ATENCION':  fila['CENTRO-ATENCION'],
                          'CASOS-MUJERES':    fila['CASOS-MUJERES'],
                          'VIOLENCIA':        'Psicologica',
                          'EDAD':             random.randint(18, 29)
                          }
            dfnew = dfnew.append(nueva_fila, ignore_index=True)

        #V.SEXUAL
        rng_3  = fila['30_59']
        for i in range(1, rng_3 + 1):
            nueva_fila = {'ANIO':             fila['ANIO'],
                          'DEPARTAMENTO':     fila['DEPARTAMENTO'],
                          'DISTRITO':         fila['DISTRITO'],
                          'CENTRO-ATENCION':  fila['CENTRO-ATENCION'],
                          'CASOS-MUJERES':    fila['CASOS-MUJERES'],
                          'VIOLENCIA':        'Sexual',
                          'EDAD':             random.randint(30, 49)
                          }
            dfnew = dfnew.append(nueva_fila, ignore_index=True)


        #V.FISICA
        rng_4  = fila['12_17']
        for i in range(1, rng_4 + 1):
            nueva_fila = {'ANIO':             fila['ANIO'],
                          'DEPARTAMENTO':     fila['DEPARTAMENTO'],
                          'DISTRITO':         fila['DISTRITO'],
                          'CENTRO-ATENCION':  fila['CENTRO-ATENCION'],
                          'CASOS-MUJERES':    fila['CASOS-MUJERES'],
                          'VIOLENCIA':        'Fisica',
                          'EDAD':             random.randint(12, 17)
                          }
            dfnew = dfnew.append(nueva_fila, ignore_index=True)

        rng_5  = fila['60_MAS']
        for i in range(1, rng_5 + 1):
            nueva_fila = {'ANIO':             fila['ANIO'],
                          'DEPARTAMENTO':     fila['DEPARTAMENTO'],
                          'DISTRITO':         fila['DISTRITO'],
                          'CENTRO-ATENCION':  fila['CENTRO-ATENCION'],
                          'CASOS-MUJERES':    fila['CASOS-MUJERES'],
                          'VIOLENCIA':        'Fisica',
                          'EDAD':             random.randint(60, 80)
                          }
            dfnew = dfnew.append(nueva_fila, ignore_index=True)

        #V.ECON_O_PATRIM
        rng_6  = fila['0_5']
        for i in range(1, rng_6 + 1):
            nueva_fila = {'ANIO':             fila['ANIO'],
                          'DEPARTAMENTO':     fila['DEPARTAMENTO'],
                          'DISTRITO':         fila['DISTRITO'],
                          'CENTRO-ATENCION':  fila['CENTRO-ATENCION'],
                          'CASOS-MUJERES':    fila['CASOS-MUJERES'],
                          #'VIOLENCIA':        'Economica',
                          'VIOLENCIA':        'Sexual',
                          'EDAD':             random.randint(1, 5)
                          }
            dfnew = dfnew.append(nueva_fila, ignore_index=True)

dfnew.to_csv('dfnew.csv', index=False, encoding='ISO-8859-1')
dfnew
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# <ipython-input-29-c9b32ddebc20>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfnew = dfnew.append(nueva_fila, ignore_index=True)
# <ipython-input-29-c9b32ddebc20>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfnew = dfnew.append(nueva_fila, ignore_index=True)
# <ipython-input-29-c9b32ddebc20>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfnew = dfnew.append(nueva_fila, ignore_index=True)
# <ipython-input-29-c9b32ddebc20>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfnew = dfnew.append(nueva_fila, ignore_index=True)
# ...
